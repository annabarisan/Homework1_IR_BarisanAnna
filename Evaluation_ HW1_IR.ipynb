# %% [markdown]
# # Evaluation HOMEWORK1
# # REPERIMENTO DELL'INFORMAZIONE

# %% [markdown]
# Barisan Anna
# Matricola: 1206600
# Corso di Laurea Magistrale in Ingegneria Informatica

# %% [markdown]
# <h2>Tabella con i valori calcolati</h2>
# <h2>MAP, Rprec, Precision at 10</h2>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
MAP = np.array([0.2125, 0.2123, 0.1245, 0.1876])
Rprec = np.array([0.2705, 0.2725, 0.1701, 0.2485])
Precision_10 = np.array([0.4820, 0.4780, 0.3020, 0.4260])
models = np.array(['BM25_SL+PS', 'TF*IDF_SL+PS', 'BM25_NoSL+PS', 'TF*IDF_NoSL+NoPS'   ])
d = {'MAP': MAP, 'Rprec': Rprec, 'Precision@10': Precision_10}

# %%
results = pd.DataFrame(data=d)
results.rename({0:'BM25_Stoplist_PorterStemmer', 1:'TF*IDF_Stoplist_PorterStemmer', 2:'BM25_NOStoplist_PorterStemmer', 3:'TF*IDF_NOStoplist_NOPorterStemmer'})
# Out:
#                                       MAP   Rprec  Precision@10
# BM25_Stoplist_PorterStemmer        0.2125  0.2705         0.482
# TF*IDF_Stoplist_PorterStemmer      0.2123  0.2725         0.478
# BM25_NOStoplist_PorterStemmer      0.1245  0.1701         0.302
# TF*IDF_NOStoplist_NOPorterStemmer  0.1876  0.2485         0.426

# %% [markdown]
# <h2>Plot singoli</h2>

# %% [markdown]
# <h3>MAP</h3>

# %%
plt.figure(1)
plt.plot(models, MAP, 'o', markersize=8)
plt.grid(True)
plt.xlabel('MODELS')
plt.ylabel('MAP VALUES')
plt.title('MAP')
plt.show()

# %% [markdown]
# <h3>Rprec</h3>

# %%
plt.figure(2)
plt.plot(models, Rprec , 'o', markersize=8)
plt.grid(True)
plt.xlabel('MODELS')
plt.ylabel('Rprec VALUES')
plt.title('Rprec')
plt.show()

# %% [markdown]
# <h3>Precision at 10</h3>

# %%
plt.figure(3)
plt.plot(models, Precision_10 , 'o', markersize=8)
plt.grid(True)
plt.xlabel('MODELS')
plt.ylabel('Precision@10 VALUES')
plt.title('Precision at 10')
plt.show()

# %% [markdown]
# <h2>Le tre misure insieme</h2>

# %%
plt.figure(4, figsize=(10,7))
p1= plt.plot(models, MAP, 'o', markersize=10, label = "MAP")
p2 = plt.plot(models, Rprec , 'o', marker = "^", markersize=10, label = 'Rprec')
p3 = plt.plot(models, Precision_10 , 'o', marker = "s", markersize=10, label = 'Precision at 10')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.grid(True)
plt.title('MAP, Rprec e Precision at 10')
plt.xlabel('MODELS')
plt.show()

# %% [markdown]
# Dalle misure riportate sopra si intuisce che i sistemi più performanti siano "BM25_SL+PS" e "TF*IDF_SL+PS" (i tre valori distano di pochissimo). Il peggiore risulta il terzo modello "BM25_NoSL+PS" mentre "TF*IDF_NoSL+NoPS" si colloca nel mezzo.

# %% [markdown]
#
#
#
#
# Carico i valori corrispettivi ai quattro diversi sistemi utilizzati.
# Ho trasformato i file di valutazione in formato .csv (in modo da poter caricare i valori); i file .csv sono presenti all'interno del repository.

# %% [markdown]
# <h3>BM25_Stoplist_PorterStemmer</h3>

# %% [markdown]
# Carico i valori di map.

# %%
filename = "BM25_SL+PS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

map_values1 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "map"):
        map_values1.append(Data[i][2])

# %%
plt.figure(5)
plt.plot(map_values1, marker='o')
plt.grid(True)
plt.xlabel('Query')
plt.ylabel('MAP VALUES')
plt.title('Performance')
plt.show()

# %% [markdown]
# Carico i valori di Rprec e Precision at 10.

# %%
filename = "BM25_SL+PS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

rprec_values1 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "Rprec"):
        rprec_values1.append(Data[i][2])

# %%
filename = "BM25_SL+PS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

p10_values1 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "P_10"):
        p10_values1.append(Data[i][2])

# %% [markdown]
# <h3> TF*IDF_Stoplist_PorterStemmer</h3>

# %% [markdown]
# Carico i valori di map.

# %%
filename = "TF*IDF_SL+PS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

map_values2 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "map"):
        map_values2.append(Data[i][2])

# %%
plt.figure(5)
plt.plot(map_values2, marker='o')
plt.grid(True)
plt.xlabel('Query')
plt.ylabel('MAP VALUES')
plt.title('Performance')
plt.show()

# %% [markdown]
# Carico i valori di Rprec e Precision at 10.

# %%
filename = "TF*IDF_SL+PS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

rprec_values2 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "Rprec"):
        rprec_values2.append(Data[i][2])

# %%
filename = "TF*IDF_SL+PS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

p10_values2 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "P_10"):
        p10_values2.append(Data[i][2])

# %% [markdown]
# <h3>BM25_NOStoplist_PorterStemmer</h3>

# %% [markdown]
# Carico i valori di map.

# %%
filename = "BM25_NoSL+PS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

map_values3 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "map"):
        map_values3.append(Data[i][2])

# %%
plt.figure(5)
plt.plot(map_values3, marker='o')
plt.grid(True)
plt.xlabel('Query')
plt.ylabel('MAP VALUES')
plt.title('Performance')
plt.show()

# %% [markdown]
# Carico i valori di Rprec e Precision at 10.

# %%
filename = "BM25_NoSL+PS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

rprec_values3 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "Rprec"):
        rprec_values3.append(Data[i][2])

# %%
filename = "BM25_NoSL+PS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

p10_values3 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "P_10"):
        p10_values3.append(Data[i][2])

# %% [markdown]
# <h3>BM25_NOStoplist_NOPorterStemmer</h3>

# %% [markdown]
# Carico i valori di map.

# %%
filename = "TF*IDF_NoSL+NoPS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

map_values4 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "map"):
        map_values4.append(Data[i][2])

# %%
plt.figure(5)
plt.plot(map_values4, marker='o')
plt.grid(True)
plt.xlabel('Query')
plt.ylabel('MAP VALUES')
plt.title('Performance')
plt.show()

# %% [markdown]
# Carico i valori di Rprec e Precision at 10.

# %%
filename = "TF*IDF_NoSL+NoPS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

rprec_values4 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "Rprec"):
        rprec_values4.append(Data[i][2])

# %%
filename = "TF*IDF_NoSL+NoPS.csv"
dt = np.dtype([('name', np.unicode_, 16), ('query', np.float64, (1,)), ('value', np.float64, (1,))])
Data = np.genfromtxt(filename, delimiter = ';', dtype = dt)

p10_values4 = []
for i in range(Data.shape[0]):
    if(Data[i][0] == "P_10"):
        p10_values4.append(Data[i][2])

# %% [markdown]
# <h1>ANOVA one-way</h1>

# %% [markdown]
# <h3>PLOT estimators MAP</h3>

# %% [markdown]
# Eseguo ora il test statistico utilizzando i valori di MAP.

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

#create the table with all values
name1 = ['BM25_SL+PS']*50
name2 = ['TF*IDF_SL+PS']*50
name3 = ['BM25_NoSL+PS']*50
name4 = ['TF*IDF_NoSL+NoPS']*50
d = {'value': map_values1 + map_values2 + map_values3 + map_values4, 
     'model': name1 + name2 + name3 + name4}

results = pd.DataFrame(data=d)
#print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-72fdb65a7354> in <module>()
#       7 name3 = ['BM25_NoSL+PS']*50
#       8 name4 = ['TF*IDF_NoSL+NoPS']*50
# ----> 9 d = {'value': map_values1 + map_values2 + map_values3 + map_values4,
#      10      'model': name1 + name2 + name3 + name4}
#      11
#
# NameError: name 'map_values1' is not defined

# %%
results.boxplot('value', by = 'model', figsize=(12,10), fontsize = 15)
plt.title('Boxplot')
plt.ylabel('Average Precision (MAP)')
plt.xlabel('MODEL')
plt.show()

# %% [markdown]
# Modelli:
# - BM25_SL+PS : BM25, Stoplist, Porter Stemmer
# - TF*IDF_SL+PS : TF*IDF, Stoplist, Porter Stemmer
# - BM25_NoSL+PS : BM25, No Stoplist, Porter Stemmer
# - TF*IDF_NoSL+NoPS : TF*IDF, No Stoplist, No Stemmer

# %% [markdown]
# Il grafico dei boxplot mostra che le distribuzioni non sono molto diverse fra loro nelle dimensioni, ad eccezione di "BM25_NoSL+PS" che  risulta la peggiore in termini di risultati; gli elementi mediani rappresentano i valori di MAP di ciascuna run e si intuisce quindi che i sistemi "BM25_SL+PS" e "TF*IDF_SL+PS" siano migliori di "BM25_NoSL+PS".

# %% [markdown]
#
#
# Eseguire il test statistico ANOVA permette di vedere se ci sono differenze statisticamente significative tra diversi gruppi di variabili, nel nostro caso se ci sono differenze tra i diversi modelli usati per la creazione dell'indice e nel reperimento. Vedere quindi se c'è una relazione tra il modello e le specifiche fasi (rimozione delle stopword e stemming) utilizzate e il conseguente indice creato, che è stato poi valutato.
# Vogliamo verificare se la null hypothesis si verifica, ovvero se le quattro distribuzioni sono congruenti.
# Utilizziamo la funzione
#
#     stats.f_oneway
#
# per eseguire il calcolo.

# %%
f, pvalue = stats.f_oneway(map_values1, map_values2, map_values3, map_values4)
print("F: " + str(f))
print("P-value: " + str(pvalue))
# Out:
# F: [3.27623957]
# P-value: [0.02214361]

# %% [markdown]
# La null hypothesis viene rigettata in quanto $p\leq\alpha$  ( $0.02214\leq0.05$ ); possiamo affermare perciò che almeno un modello ha una media con differenza statisticamente significativa rispetto ad un altro modello ma non possiamo ancora dire quale: dobbiamo confrontare ogni coppia di modelli per determinare quali sono quelle significativamente differenti e per fare questo eseguiremo il test di Turkey utilizzando la multiple comparison.

# %% [markdown]
# <h2>Test di TURKEY MAP</h2>

# %% [markdown]
# Eseguiamo il test di Turkey per determinare qual è/quali sono i modelli significativamente differenti,  utilizzando la multiple comparison.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

values = np.array(map_values1 + map_values2 + map_values3 + map_values4)
model = np.array(name1 + name2 + name3 + name4)

mc = MultiComparison(values, model)
results = mc.tukeyhsd()
print(results)
print(mc.groupsunique)
# Out:
#        Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ================================================================
#      group1           group2      meandiff  lower  upper  reject
# ----------------------------------------------------------------
#   BM25_NoSL+PS      BM25_SL+PS     0.088    0.004  0.1721  True
#   BM25_NoSL+PS   TF*IDF_NoSL+NoPS  0.0632  -0.0209 0.1472 False
#   BM25_NoSL+PS     TF*IDF_SL+PS    0.0878   0.0037 0.1718  True
#    BM25_SL+PS    TF*IDF_NoSL+NoPS -0.0249  -0.1089 0.0591 False
#    BM25_SL+PS      TF*IDF_SL+PS   -0.0003  -0.0843 0.0838 False
# TF*IDF_NoSL+NoPS   TF*IDF_SL+PS    0.0246  -0.0594 0.1087 False
# ----------------------------------------------------------------
# ['BM25_NoSL+PS' 'BM25_SL+PS' 'TF*IDF_NoSL+NoPS' 'TF*IDF_SL+PS']

# %% [markdown]
# Le colonne "group1" e "group2" sono la coppia che viene confrontata, la colonna "meandiff" è la differenza nelle medie dei due gruppi calcolati come group2-gruop1, le colonne "lower" e "upper" rappresentano i limiti inferiore e superiore dell'intervallo di confidenza e l'ultima colonna indica se la null hypotesis deve essere rifiutata o meno.
#
# Si può notare che il primo e il terzo intervallo non contengono l'origine e quindi comportano un rifiuto dell'ipotesi H0 evidenziando l'importante differenza tra i modelli "BM25_NoSL+PS"-"BM25_SL+PS" e "BM25_NoSL+PS"-"TF*IDF_SL+PS".
# Ciò si può osservare anche nei plot seguenti.
# Possiamo concludere quindi, per quanto riguarda questo test statistico sui valori di MAP, che i sistemi appartenenti al top group sono i primi due "BM25_SL+PS" e "TF*IDF_SL+PS"; essi sono significativamente diversi dal terzo modello "BM25_NoSL+PS" che non appartiene a questa categoria. Il quarto modello "TF*IDF_NoSL+NoPS" non è diverso dai primi due, però si intuisce una differenza, tenendo anche presente che esso non risulta significativamente diverso dal terzo sistema.

# %%
results.plot_simultaneous(comparison_name="BM25_NoSL+PS")

# %% [markdown]
# Eseguo ora lo stesso procedimento, ANOVA 1-way e test di Turkey per i valori di Rprec.

# %% [markdown]
# <h3>PLOT estimators Rprec</h3>

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

#create the table with all values
name1 = ['BM25_SL+PS']*50
name2 = ['TF*IDF_SL+PS']*50
name3 = ['BM25_NoSL+PS']*50
name4 = ['TF*IDF_NoSL+NoPS']*50
d2 = {'value': rprec_values1 + rprec_values2 + rprec_values3 + rprec_values4, 
     'model': name1 + name2 + name3 + name4}

results2 = pd.DataFrame(data=d2)
#print(results)

# %%
results2.boxplot('value', by = 'model', figsize=(12,10), fontsize = 15)
plt.title('Boxplot')
plt.ylabel('Rprec')
plt.xlabel('MODEL')
plt.show()

# %%
f, pvalue = stats.f_oneway(rprec_values1, rprec_values2, rprec_values3, rprec_values4)
print("F: " + str(f))
print("P-value: " + str(pvalue))
# Out:
# F: [4.56014011]
# P-value: [0.00411144]

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

values2 = np.array(rprec_values1 + rprec_values2 + rprec_values3 + rprec_values4)
model2 = np.array(name1 + name2 + name3 + name4)

mc2 = MultiComparison(values2, model2)
results2 = mc2.tukeyhsd()
print(results2)
print(mc2.groupsunique)
# Out:
#        Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ================================================================
#      group1           group2      meandiff  lower  upper  reject
# ----------------------------------------------------------------
#   BM25_NoSL+PS      BM25_SL+PS     0.1004   0.0179 0.1829  True
#   BM25_NoSL+PS   TF*IDF_NoSL+NoPS  0.0784  -0.0042 0.1609 False
#   BM25_NoSL+PS     TF*IDF_SL+PS    0.1023   0.0198 0.1849  True
#    BM25_SL+PS    TF*IDF_NoSL+NoPS  -0.022  -0.1046 0.0605 False
#    BM25_SL+PS      TF*IDF_SL+PS    0.0019  -0.0806 0.0845 False
# TF*IDF_NoSL+NoPS   TF*IDF_SL+PS    0.024   -0.0586 0.1065 False
# ----------------------------------------------------------------
# ['BM25_NoSL+PS' 'BM25_SL+PS' 'TF*IDF_NoSL+NoPS' 'TF*IDF_SL+PS']

# %% [markdown]
# Il grafico dei boxplot è molto simile al precedente. Anche qui le distribuzioni non sono molto diverse fra loro nelle dimensioni, ad eccezione di "BM25_NoSL+PS" che  risulta la peggiore in termini di risultati; si intuisce, coerentemente con i dati sopra, che i sistemi "BM25_SL+PS" e "TF*IDF_SL+PS" siano migliori.
#
# Come in precedenza la null hypothesis viene rigettata in quanto $p\leq\alpha$  ( $0.00411144\leq0.05$ ); eseguendo il test di Turkey utilizzando la multiple comparison si nota che il primo e il terzo intervallo non contengono l'origine e quindi comportano un rifiuto dell'ipotesi H0 evidenziando la differenza tra i modelli "BM25_NoSL+PS" - "BM25_SL+PS" e "BM25_NoSL+PS" - "TF*IDF_SL+PS".
# Ciò si può osservare anche nei plot seguenti.
# Anche per quanto riguarda questa parte (test statistico sui valori di Rprec) i sistemi appartenenti al top group risultano i primi due "BM25_SL+PS" e "TF*IDF_SL+PS", diversi dal peggiore "BM25_NoSL+PS".

# %%
results2.plot_simultaneous(comparison_name="BM25_NoSL+PS")

# %% [markdown]
# Eseguo ora lo stesso procedimento, ANOVA 1-way e test di Turkey per i valori di Precision at 10.

# %% [markdown]
# <h3>PLOT estimators Precision at 10</h3>

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

#create the table with all values
name1 = ['BM25_SL+PS']*50
name2 = ['TF*IDF_SL+PS']*50
name3 = ['BM25_NoSL+PS']*50
name4 = ['TF*IDF_NoSL+NoPS']*50
d3 = {'value': p10_values1 + p10_values2 + p10_values3 + p10_values4, 
     'model': name1 + name2 + name3 + name4}

results3 = pd.DataFrame(data=d3)
#print(results)

# %%
results3.boxplot('value', by = 'model', figsize=(12,10), fontsize = 15)
plt.title('Boxplot')
plt.ylabel('Precision at 10')
plt.xlabel('MODEL')
plt.show()

# %%
f, pvalue = stats.f_oneway(p10_values1, p10_values2, p10_values3, p10_values4)
print("F: " + str(f))
print("P-value: " + str(pvalue))
# Out:
# F: [3.88060685]
# P-value: [0.01003255]

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

values3 = np.array(p10_values1 + p10_values2 + p10_values3 + p10_values4)
model3 = np.array(name1 + name2 + name3 + name4)

mc3 = MultiComparison(values3, model3)
results3 = mc3.tukeyhsd()
print(results3)
print(mc3.groupsunique)
# Out:
#        Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ================================================================
#      group1           group2      meandiff  lower  upper  reject
# ----------------------------------------------------------------
#   BM25_NoSL+PS      BM25_SL+PS      0.18    0.0238 0.3362  True
#   BM25_NoSL+PS   TF*IDF_NoSL+NoPS  0.124   -0.0322 0.2802 False
#   BM25_NoSL+PS     TF*IDF_SL+PS    0.176    0.0198 0.3322  True
#    BM25_SL+PS    TF*IDF_NoSL+NoPS  -0.056  -0.2122 0.1002 False
#    BM25_SL+PS      TF*IDF_SL+PS    -0.004  -0.1602 0.1522 False
# TF*IDF_NoSL+NoPS   TF*IDF_SL+PS    0.052   -0.1042 0.2082 False
# ----------------------------------------------------------------
# ['BM25_NoSL+PS' 'BM25_SL+PS' 'TF*IDF_NoSL+NoPS' 'TF*IDF_SL+PS']

# %% [markdown]
# Il grafico dei boxplot è nuovamente simile ai precedenti anche se qui le distribuzioni sono traslate. Le considerazioni fatte in precedenza valgono.
# La null hypothesis viene rigettata in quanto $p\leq\alpha$  ( $0.01003255\leq0.05$ ) e i modelli diversi sono gli stessi dei due test precedenti.

# %%
results3.plot_simultaneous(comparison_name="BM25_NoSL+PS")

# %% [markdown]
# Si può concludere quindi che complessivamente i test statistici sulle tre misure hanno portato agli stessi risultati. I sistemi appartenenti al top group sono i primi due "BM25_SL+PS" e "TF*IDF_SL+PS"; sicuramente il terzo modello "BM25_NoSL+PS", diverso da essi, non appartiene ad esso. Il quarto modello "TF*IDF_NoSL+NoPS" si colloca nel mezzo, non è significativamente differente dagli altri.
